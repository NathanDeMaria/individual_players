# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
league = "mens"
prior = "_team_prior"
year = 2023

# %%
player_ratings = pd.read_csv(f"./data/{league}_player_ratings{prior}.csv", index_col=0)
# https://www.espn.com/womens-college-basketball/player/_/id/5174285/milaysia-fulwiley
# is not in player_info
player_info = (
    pd.read_csv(f"./data/{league}_player_info.csv", index_col="player_id")
    .assign(team_id=lambda _: pd.to_numeric(_.team_id, errors="coerce"))
    .dropna(subset=["team_id"])
    .assign(team_id=lambda _: _.team_id.astype(int))
)
defense_ratings = pd.read_csv(  
    f"./data/{league}_player_ratings_defense{prior}.csv", index_col=0
)

player_ratings = (
    player_ratings.merge(player_info, left_index=True, right_index=True, how="left")
    .assign(team_id=lambda _: pd.to_numeric(_.team_id, errors="coerce"))
    .dropna(subset=["team_id"])
    .merge(defense_ratings, left_index=True, right_index=True, suffixes=("", "_defense"))
    .assign(net_vpp=lambda _: _.vpp - _.vpp_defense)
)
teams = (
    player_info.reset_index()[["team_name", "team_id"]]
    .drop_duplicates()
    .set_index("team_id")
)

# %%
performances = pd.read_csv(f"./data/all_performances_{league}_{year}.csv")
most_recent_games = (
    performances.groupby("team_id")
    .agg({"game_id": "max"})
    .rename(columns={"game_id": "most_recent_game"})
)
performances = (
    performances.merge(most_recent_games, left_on="team_id", right_index=True)
    .assign(is_most_recent=lambda _: _.most_recent_game == _.game_id)
)
in_most_recent = set(performances[performances.is_most_recent].player_id)

# %%
weighted_players = pd.concat([(
        team.groupby("player_id")
            .agg({"n_possessions": "sum"})
            .reset_index()
            .assign(pct_possessions=lambda df: 5 * df.n_possessions / df.n_possessions.sum())
            .sort_values("pct_possessions", ascending=False)
            .assign(team_id=team_id)
    )
    for team_id, team in performances.groupby("team_id")
]).set_index("player_id")
weighted_players = (
    weighted_players.merge(player_ratings, left_index=True, right_index=True, suffixes=("", "_right"))
        .assign(played_in_latest=lambda _: [pid in in_most_recent for pid in _.index])
)

# %%
# re-scale up to full net_impacts for each team
weighted_players = weighted_players.assign(pct_possessions=lambda _: _.pct_possessions * _.played_in_latest)
multipliers = (
    weighted_players.groupby("team_id")
    .agg({"pct_possessions": "sum"})
    .assign(multiplier=lambda _: 5 / _.pct_possessions)
    .drop(columns=["pct_possessions"])
)
weighted_players = (
    weighted_players.merge(multipliers, on="team_id")
    .assign(player_impact=lambda _: _.net_vpp * _.pct_possessions * _.multiplier)
)

# %%
team_ratings = (
    weighted_players
        .groupby("team_id")
        .agg({"player_impact": "sum"})
)

# %%
pretty_players = (
    weighted_players.sort_values("net_vpp", ascending=False)[["player_name", "team_name", "net_vpp", "player_impact", "vpp", "vpp_defense", "n_possessions", "Class"]]
    .assign(rank=lambda _: _.net_vpp.rank(ascending=False))
)

# %%
# TODO: get the team names directly
# Some team ids have multiple team names
# I think it's because things can get weird with transfers
# so I'm taking the "mode", hopefully that's better
team_names = weighted_players.groupby("team_id").agg({"team_name": pd.Series.mode})
team_ratings = (
    team_ratings.merge(team_names, left_index=True, right_index=True)
        .sort_values("player_impact", ascending=False)
        .assign(rank=lambda _: _.player_impact.rank(ascending=False))
)

# %%
team_ratings.head(25)
# Out:
#          player_impact                 team_name  rank
# team_id
# 57            0.714846            florida-gators   1.0
# 167           0.706704          new-mexico-lobos   2.0
# 245           0.702745           texas-am-aggies   3.0
# 2509          0.699548       purdue-boilermakers   4.0
# 2599          0.685956        st-johns-red-storm   5.0
# 265           0.679691  washington-state-cougars   6.0
# 2             0.675386             auburn-tigers   7.0
# 2294          0.664356             iowa-hawkeyes   8.0
# 333           0.657140      alabama-crimson-tide   9.0
# 41            0.653510             uconn-huskies  10.0
# 96            0.649437         kentucky-wildcats  11.0
# 156           0.644191        creighton-bluejays  12.0
# 356           0.636669  illinois-fighting-illini  13.0
# 251           0.630354           texas-longhorns  14.0
# 8             0.624091       arkansas-razorbacks  15.0
# 2633          0.624078      tennessee-volunteers  16.0
# 232           0.622966        charleston-cougars  17.0
# 119           0.622225             towson-tigers  18.0
# 2628          0.622204          tcu-horned-frogs  19.0
# 2483          0.620561              oregon-ducks  20.0
# 239           0.619340              baylor-bears  21.0
# 158           0.618536      nebraska-cornhuskers  22.0
# 2253          0.615675        grand-canyon-lopes  23.0
# 299           0.615499    long-beach-state-beach  24.0
# 21            0.612790    san-diego-state-aztecs  25.0

# %%
pretty_players.head(25)
# Out:
#                player_name                    team_name   net_vpp  \
# 3925             Zach Edey          purdue-boilermakers  0.313449
# 253        Donovan Clingan                uconn-huskies  0.243756
# 2112           Greg Gordon                   iona-gaels  0.236750
# 3051           Braden Huff             gonzaga-bulldogs  0.234433
# 3320         Dame Adelekun      loyola-chicago-ramblers  0.230341
# 1072      Ryan Kalkbrenner           creighton-bluejays  0.228165
# 3540           Drew Pember       unc-asheville-bulldogs  0.226843
# 0             Johni Broome                auburn-tigers  0.225616
# 3836          N'Faly Dante                 oregon-ducks  0.224659
# 4240  Collin Murray-Boyles     south-carolina-gamecocks  0.224380
# 801             Josh Cohen      massachusetts-minutemen  0.220528
# 3623           Kalib Boone                  unlv-rebels  0.219316
# 1181             JT Toppin             new-mexico-lobos  0.218609
# 1794           Isaac Jones     washington-state-cougars  0.216452
# 2763       DaRon Holmes II                dayton-flyers  0.215965
# 2893         Isaiah Cozart    eastern-kentucky-colonels  0.211925
# 3171      Hunter Dickinson              kansas-jayhawks  0.211694
# 4009            Alex Sobel        sacred-heart-pioneers  0.211162
# 1349           PJ Haggerty       tulsa-golden-hurricane  0.210612
# 110           Jaedon LeDee       san-diego-state-aztecs  0.208025
# 4960        Jimmy Salamone  ohio-christian-trailblazers  0.206640
# 1976       Robert McCray V        jacksonville-dolphins  0.206363
# 4034           Achor Achor             samford-bulldogs  0.204828
# 3498           Riley Minix        morehead-state-eagles  0.204637
# 1576            Yves Missi                 baylor-bears  0.202313
#
#       player_impact       vpp  vpp_defense  n_possessions      Class  rank
# 3925       0.247815  0.320055     0.006606    1796.901106     Senior   1.0
# 253        0.125992  0.269305     0.025549    1072.752187  Sophomore   2.0
# 2112       0.000000  0.258161     0.021411    1060.243125     Junior   3.0
# 3051       0.083488  0.284490     0.050057     732.636875   Freshman   4.0
# 3320       0.100117  0.236570     0.006229     926.450250     Senior   5.0
# 1072       0.208248  0.230172     0.002007    1857.692412     Senior   6.0
# 3540       0.174978  0.238625     0.011782    1677.704097     Senior   7.0
# 0          0.143512  0.230781     0.005165    1507.026875     Junior   8.0
# 3836       0.111978  0.229586     0.004927    1051.888438     Senior   9.0
# 4240       0.117293  0.239532     0.015152    1007.329479   Freshman  10.0
# 801        0.161606  0.227532     0.007004    1576.063854     Senior  11.0
# 3623       0.000000  0.218553    -0.000763    1099.628722     Senior  12.0
# 1181       0.151086  0.218683     0.000074    1677.662820   Freshman  13.0
# 1794       0.182062  0.221790     0.005338    1777.931355     Senior  14.0
# 2763       0.178184  0.232096     0.016132    1633.457847     Junior  15.0
# 2893       0.174063  0.221773     0.009848    1601.605417     Senior  16.0
# 3171       0.000000  0.215274     0.003579    1699.778438     Senior  17.0
# 4009       0.163097  0.229613     0.018451    1348.613750     Senior  18.0
# 1349       0.183169  0.221211     0.010599    1833.895903   Freshman  19.0
# 110        0.168825  0.218476     0.010451    1762.993576     Senior  20.0
# 4960       0.134316  0.219658     0.013018      46.450625         --  21.0
# 1976       0.162241  0.218844     0.012481    1558.072569  Sophomore  22.0
# 4034       0.116190  0.226323     0.021495    1277.419300     Junior  23.0
# 3498       0.182821  0.233937     0.029300    1738.511250     Senior  24.0
# 1576       0.126346  0.202408     0.000095    1217.429271   Freshman  25.0

# %%
def _team_summary(team: str):
    print(team_ratings[team_ratings.team_name == team])
    return pretty_players[pretty_players.team_name == team]

# %%
_team_summary("tennessee-volunteers")
# Out:
#          player_impact             team_name  rank
# team_id
# 2633          0.624078  tennessee-volunteers  16.0
#               player_name             team_name   net_vpp  player_impact  \
# 4415        Dalton Knecht  tennessee-volunteers  0.169036       0.130039
# 4418          Jonas Aidoo  tennessee-volunteers  0.156197       0.101462
# 4421           Tobe Awaka  tennessee-volunteers  0.149860       0.047770
# 4414        Zakai Zeigler  tennessee-volunteers  0.133357       0.105199
# 873      Olivier Nkamhoua  tennessee-volunteers  0.119763       0.000000
# 4419        Jordan Gainey  tennessee-volunteers  0.104474       0.049447
# 4420       Jahmai Mashack  tennessee-volunteers  0.103407       0.046580
# 4417     Santiago Vescovi  tennessee-volunteers  0.101570       0.066720
# 4416  Josiah-Jordan James  tennessee-volunteers  0.098762       0.073437
# 4422        J.P. Estrella  tennessee-volunteers  0.033284       0.002627
# 4427          Grant Hurst  tennessee-volunteers  0.024359       0.000000
# 4423    Freddie Dilione V  tennessee-volunteers  0.011327       0.000797
# 4424        Cade Phillips  tennessee-volunteers  0.008999       0.000000
# 4429         Kaylan Makan  tennessee-volunteers -0.000334      -0.000000
# 4428       D.J. Jefferson  tennessee-volunteers -0.000612      -0.000000
# 4426          Colin Coyne  tennessee-volunteers -0.009050      -0.000000
# 4425         Cameron Carr  tennessee-volunteers -0.009503      -0.000000
#
#            vpp  vpp_defense  n_possessions      Class    rank
# 4415  0.180175     0.011139    1714.427500     Senior   117.0
# 4418  0.171762     0.015565    1447.622813     Junior   214.0
# 4421  0.164638     0.014777     710.389688  Sophomore   272.0
# 4414  0.143854     0.010496    1758.003438     Junior   511.0
# 873   0.132738     0.012975    1535.519072     Senior   836.0
# 4419  0.121937     0.017463    1054.771563     Junior  1316.0
# 4420  0.120840     0.017432    1003.867500     Junior  1353.0
# 4417  0.110080     0.008509    1463.910938     Senior  1426.0
# 4416  0.108066     0.009303    1657.090312     Senior  1530.0
# 4422  0.043584     0.010301     175.925000   Freshman  3631.0
# 4427  0.027995     0.003636       8.969688  Sophomore  3761.0
# 4423  0.049803     0.038476     156.836250   Freshman  3952.0
# 4424  0.032380     0.023381     135.453438   Freshman  3989.0
# 4429  0.001296     0.001631       3.544375  Sophomore  4250.0
# 4428  0.002340     0.002953       5.316562   Freshman  4284.0
# 4426  0.001631     0.010681      12.587813     Senior  4634.0
# 4425  0.023376     0.032878      98.345625   Freshman  4642.0

# %%
_team_summary("saint-peters-peacocks")
# Out:
#          player_impact              team_name   rank
# team_id
# 2612          0.405021  saint-peters-peacocks  303.0
#            player_name              team_name   net_vpp  player_impact  \
# 4324  Corey Washington  saint-peters-peacocks  0.175076       0.101919
# 4327     Michael Houge  saint-peters-peacocks  0.170200       0.057898
# 4326    Armoni Zeigler  saint-peters-peacocks  0.103109       0.050770
# 4328   Stephon Roberts  saint-peters-peacocks  0.080115       0.026401
# 4323      Mouhamed Sow  saint-peters-peacocks  0.064208       0.038609
# 4325   Marcus Randolph  saint-peters-peacocks  0.063916       0.033202
# 4329       Elijah Wood  saint-peters-peacocks  0.054795       0.000000
# 4321        Roy Clarke  saint-peters-peacocks  0.053621       0.034833
# 4320      Latrell Reid  saint-peters-peacocks  0.044818       0.038788
# 4322       Brent Bland  saint-peters-peacocks  0.036457       0.022600
# 4330    Elijah Perkins  saint-peters-peacocks -0.027048      -0.000000
#
#            vpp  vpp_defense  n_possessions      Class    rank
# 4324  0.194884     0.019808    1134.994688  Sophomore    81.0
# 4327  0.165519    -0.004681     663.241389     Junior   110.0
# 4326  0.123601     0.020492     960.003229   Freshman  1364.0
# 4328  0.103916     0.023801     642.486007     Senior  2251.0
# 4323  0.078114     0.013906    1172.360660     Junior  2832.0
# 4325  0.077578     0.013662    1012.786042     Junior  2842.0
# 4329  0.070182     0.015387     288.068472     Junior  3119.0
# 4321  0.073022     0.019401    1266.537361     Senior  3156.0
# 4320  0.062296     0.017478    1687.387292     Senior  3382.0
# 4322  0.055818     0.019361    1208.607396   Freshman  3561.0
# 4330 -0.026344     0.000704     241.714965  Sophomore  4890.0
